# %%
import pandas as pd
import matplotlib.pyplot as plt

# Creating the DataFrame directly from the provided data
data = pd.DataFrame({
    'Models': ['NB', 'NB', 'NB', 'NB', 'NB', 'NB', 'NB', 'NB',
               'SVM', 'SVM', 'SVM', 'SVM', 'SVM', 'SVM', 'SVM', 'SVM',
               'MLP', 'MLP', 'MLP', 'MLP', 'MLP', 'MLP', 'MLP', 'MLP',
               'Cat Boost', 'Cat Boost', 'Cat Boost', 'Cat Boost', 'Cat Boost', 'Cat Boost', 'Cat Boost', 'Cat Boost',
               'Tab Net', 'Tab Net', 'Tab Net', 'Tab Net', 'Tab Net', 'Tab Net', 'Tab Net', 'Tab Net'],
    'Type': ['I', 'II', 'III', 'IV', 'V', 'VI', 'VII', 'VIII'] * 5,
    'Precision': [82.91, 82.10, 81.97, 77.57, 72.85, 72.85, 72, 90,
                  93.61, 84.96, 90.98, 87.38, 82.85, 89.22, 90.98, 87.38,
                  94.32, 90.26, 94.54, 92.29, 85, 93.62, 87.38, 93,
                  89.22, 90.98, 87.54, 87.29, 92.10, 81.97, 67.57, 88,
                  92.91, 95.57, 99.18, 92.79, 100, 97.6, 96, 100],
    'TPR': [91.62, 75.92, 86.96, 76.54, 84.45, 84.45, 84.78, 91.17,
            93.62, 88.07, 90.24, 85.09, 84.45, 87, 90.24, 85.09,
            93.66, 90.26, 88.35, 87.29, 85, 93.6, 84.09, 86,
            93.66, 90.26, 93.6, 84.09, 94.84, 94.67, 95.33, 86,
            97.04, 88.53, 96.8, 98.09, 100, 96.8, 98.09, 93.94],
    'F1 Score': [92.25, 83.2, 84.39, 71.77, 73.65, 73.65, 73.33, 93.38,
                 93.62, 86.49, 90.61, 86.22, 83.65, 73.12, 86.96, 76.54,
                 93.99, 90.26, 87.95, 87.29, 73, 93.62, 87.38, 94.5,
                 93.99, 90.26, 93.62, 87.38, 72.85, 92, 93.62, 94.5,
                 94.93, 91.92, 97.98, 95.37, 100, 97.98, 95.37, 96.88],
    'TNR': [92.85, 85.05, 85.47, 82.83, 84.2, 84.2, 93.05, 90,
            88.04, 86.54, 87.69, 87.12, 87.2, 89, 91.12, 84.29,
            88.25, 87.74, 89.37, 89.38, 87.2, 88.88, 87.23, 92.65,
            91.12, 84.29, 88.88, 87.23, 87, 90.24, 93.62, 94,
            97.85, 98.96, 99.79, 98.38, 100, 95.64, 99.81, 100],
    'G-mean': [86.73, 86.28, 81.12, 84.29, 75.72, 85.72, 88.1, 92.48,
               92.81, 92.21, 93.89, 90.91, 75.72, 81.37, 90.61, 86.22,
               92.93, 93.93, 88.85, 88.33, 78, 89.96, 84.55, 87.9,
               90.61, 86.22, 91.12, 84.29, 93.12, 86.96, 93.6, 94.9,
               97.45, 93.96, 98.29, 98.23, 100, 99, 99.21, 96.97]
})

# Set up a larger figure with 2 rows and 3 columns (5 metrics, so one will be empty)
fig, axes = plt.subplots(2, 3, figsize=(22, 14))

# Flatten axes for easier iteration
axes = axes.flatten()

# Metrics to plot
metrics = ['Precision', 'TPR', 'F1 Score', 'TNR', 'G-mean']
for i, metric in enumerate(metrics):
    ax = axes[i]
    for model in data['Models'].unique():
        model_data = data[data['Models'] == model]
        ax.plot(
            model_data['Type'],
            model_data[metric],
            marker='*',           # Star marker
            markersize=12,        # Larger marker size
            linestyle='-',
            linewidth=2.5,        # Bold line
            label=model
        )
    ax.set_title(metric, fontsize=18, fontweight='bold')
    ax.set_xlabel('Type', fontsize=16, fontweight='bold')
    ax.set_ylabel('Score', fontsize=16, fontweight='bold')
    
    # Set tick parameters to make x-axis and y-axis bold and large
    ax.tick_params(axis='x', labelsize=14, width=2, labelcolor='black')
    ax.tick_params(axis='y', labelsize=14, width=2, labelcolor='black')
    
    ax.legend(title='Models', loc='best', fontsize='large')

# Remove the last empty subplot (index 5)
fig.delaxes(axes[5])

# Adjust layout and add space between subplots
plt.subplots_adjust(hspace=0.4, wspace=0.3)

# Save the figure
plt.savefig("ML_model_performance_plots.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\KANAK\AppData\Local\Temp\ipykernel_35212\3020124352.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data preparation
types = ['Type I', 'Type II', 'Type III', 'Type IV', 'Type V', 'Type VI', 'Type VII', 'Type VIII']
classifiers = ['NB', 'SVM', 'MLP', 'CatBoost', 'TabNet']

precision_values = {
    'Type I': [82.91, 93.61, 94.32, 89.22, 92.91],
    'Type II': [82.10, 84.96, 90.26, 90.98, 92.91],
    'Type III': [81.97, 90.98, 94.54, 87.54, 95.57],
    'Type IV': [77.57, 87.38, 92.29, 87.29, 99.18],
    'Type V': [72.85, 82.85, 85, 92.10, 92.79],
    'Type VI': [72.85, 89.22, 93.62, 81.97, 100],
    'Type VII': [72, 90.98, 87.38, 67.57, 97.6],
    'Type VIII': [90, 87.38, 93, 88, 100]
}

# Creating subplots based on types
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(12, 6))
axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easy iteration

# Loop through the types and their precision values
for ax, type_name in zip(axes, types):
    ax.bar(classifiers, precision_values[type_name], color='blue')
    ax.set_title(f'Precision for {type_name}')
    ax.set_ylim(60, 100)  # Set y-axis limits for consistency
    #ax.set_xlabel('Classifier')
    ax.set_ylabel('Precision')
    ax.grid(axis='y', linestyle='--', alpha=0.7)

# Rotate x-tick labels
    ax.set_xticks(classifiers)  # Set x-ticks to the classifiers
    ax.set_xticklabels(classifiers, rotation=45)  # Rotate x-tick labels

# Remove any unused subplots
for i in range(len(types), len(axes)):
    fig.delaxes(axes[i])

# Adjust space between subplots
plt.subplots_adjust(wspace=0.6, hspace=0.6)

plt.savefig("precision_performance_plots.png", dpi=300, bbox_inches='tight')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data preparation
types = ['Type I', 'Type II', 'Type III', 'Type IV', 'Type V', 'Type VI', 'Type VII', 'Type VIII']
classifiers = ['NB', 'SVM', 'MLP', 'CatBoost', 'TabNet']

# TPR values for each type and classifier
tpr_values = {
    'Type I': [91.62, 93.62, 93.66, 93.66, 97.04],
    'Type II': [75.92, 88.07, 90.26, 90.26, 88.53],
    'Type III': [86.96, 90.24, 88.35, 93.6, 96.8],
    'Type IV': [76.54, 85.09, 87.29, 84.09, 98.09],
    'Type V': [84.45, 84.45, 85, 94.84, 100],
    'Type VI': [84.45, 87, 93.6, 94.67, 96.8],
    'Type VII': [84.78, 90.24, 84.09, 95.33, 98.09],
    'Type VIII': [91.17, 85.09, 86, 86, 93.94]
}

# Creating subplots based on types
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(12, 6))
axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easy iteration

# Loop through the types and their TPR values
for ax, type_name in zip(axes, types):
    ax.bar(classifiers, tpr_values[type_name], color='red')
    ax.set_title(f'TPR for {type_name}')
    ax.set_ylim(60, 100)  # Set y-axis limits for consistency
   # ax.set_xlabel('Classifier')
    ax.set_ylabel('TPR (%)')
    ax.grid(axis='y', linestyle='--', alpha=0.7)
    
    # Rotate x-tick labels for better readability
    ax.set_xticks(classifiers)  # Set x-ticks to classifiers
    ax.set_xticklabels(classifiers, rotation=45)  # Rotate x-tick labels

# Remove any unused subplots
for i in range(len(types), len(axes)):
    fig.delaxes(axes[i])

# Adjust space between subplots
plt.subplots_adjust(wspace=0.6, hspace=0.6)

plt.savefig("TPR_performance_plots.png", dpi=300, bbox_inches='tight')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data preparation
types = ['Type I', 'Type II', 'Type III', 'Type IV', 'Type V', 'Type VI', 'Type VII', 'Type VIII']
classifiers = ['NB', 'SVM', 'MLP', 'CatBoost', 'TabNet']

# F1 Score values for each type and classifier
f1_scores = {
    'Type I': [92.25, 93.62, 93.99, 93.99, 94.93],
    'Type II': [83.20, 86.49, 90.26, 90.26, 91.92],
    'Type III': [84.39, 90.61, 87.95, 93.62, 97.98],
    'Type IV': [71.77, 86.22, 87.29, 87.38, 95.37],
    'Type V': [73.65, 83.65, 73, 72.85, 100],
    'Type VI': [73.65, 73.12, 93.62, 92, 97.98],
    'Type VII': [73.33, 86.96, 87.38, 93.62, 95.37],
    'Type VIII': [93.38, 76.54, 94.5, 94.5, 96.88]
}

# Creating subplots based on types
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(12, 6))
axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easy iteration

# Loop through the types and their F1 Score values
for ax, type_name in zip(axes, types):
    ax.bar(classifiers, f1_scores[type_name], color='green')
    ax.set_title(f'F1 Score for {type_name}')
    ax.set_ylim(60, 100)  # Set y-axis limits for consistency
    #ax.set_xlabel('Classifier')
    ax.set_ylabel('F1 Score')
    ax.grid(axis='y', linestyle='--', alpha=0.7)
    
    # Rotate x-tick labels for better readability
    ax.set_xticks(classifiers)  # Set x-ticks to classifiers
    ax.set_xticklabels(classifiers, rotation=45)  # Rotate x-tick labels

# Remove any unused subplots
for i in range(len(types), len(axes)):
    fig.delaxes(axes[i])

# Adjust space between subplots
plt.subplots_adjust(wspace=0.6, hspace=0.6)

plt.savefig("F1 Score_performance_plots.png", dpi=300, bbox_inches='tight')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data preparation
types = ['Type I', 'Type II', 'Type III', 'Type IV', 'Type V', 'Type VI', 'Type VII', 'Type VIII']
classifiers = ['NB', 'SVM', 'MLP', 'CatBoost', 'TabNet']

# TNR values for each type and classifier
tnr_values = {
    'Type I': [92.85, 88.04, 88.25, 91.12, 97.85],
    'Type II': [85.05, 86.54, 87.74, 84.29, 98.96],
    'Type III': [85.47, 87.69, 89.37, 88.88, 99.79],
    'Type IV': [82.83, 87.12, 89.38, 87.23, 98.38],
    'Type V': [84.20, 87.20, 87.20, 87, 100],
    'Type VI': [84.20, 89, 88.88, 90.24, 95.64],
    'Type VII': [93.05, 91.12, 87.23, 93.62, 99.81],
    'Type VIII': [90, 84.29, 92.65, 94, 100]
}

# Creating subplots based on types
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(12, 6))
axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easy iteration

# Loop through the types and their TNR values
for ax, type_name in zip(axes, types):
    ax.bar(classifiers, tnr_values[type_name], color='black')
    ax.set_title(f'TNR for {type_name}')
    ax.set_ylim(60, 100)  # Set y-axis limits for consistency
   # ax.set_xlabel('Classifier')
    ax.set_ylabel('TNR (%)')
    ax.grid(axis='y', linestyle='--', alpha=0.7)
    
    # Rotate x-tick labels for better readability
    ax.set_xticks(range(len(classifiers)))  # Set x-ticks to classifiers
    ax.set_xticklabels(classifiers, rotation=45)  # Rotate x-tick labels

# Remove any unused subplots
for i in range(len(types), len(axes)):
    fig.delaxes(axes[i])

# Adjust space between subplots
plt.subplots_adjust(wspace=0.6, hspace=0.6)

plt.savefig("TNR_performance_plots.png", dpi=300, bbox_inches='tight')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data preparation
types = ['Type I', 'Type II', 'Type III', 'Type IV', 'Type V', 'Type VI', 'Type VII', 'Type VIII']
classifiers = ['NB', 'SVM', 'MLP', 'CatBoost', 'TabNet']

# G-Mean values for each type and classifier
gmean_values = {
    'Type I': [86.73, 92.81, 92.93, 90.61, 97.45],
    'Type II': [86.28, 92.21, 93.93, 86.22, 93.96],
    'Type III': [81.12, 93.89, 88.85, 91.12, 98.29],
    'Type IV': [84.29, 90.91, 88.33, 84.29, 98.23],
    'Type V': [75.72, 75.72, 78, 93.12, 100],
    'Type VI': [85.72, 81.37, 89.96, 86.96, 99],
    'Type VII': [88.10, 90.61, 84.55, 93.6, 99.21],
    'Type VIII': [92.48, 86.22, 87.90, 94.90, 96.97]
}

# Creating subplots based on types
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(12, 6))
axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easy iteration

# Loop through the types and their G-Mean values
for ax, type_name in zip(axes, types):
    ax.bar(classifiers, gmean_values[type_name], color='orange')
    ax.set_title(f'G-Mean for {type_name}')
    ax.set_ylim(70, 105)  # Set y-axis limits for consistency
    #ax.set_xlabel('Classifier')
    ax.set_ylabel('G-Mean')
    ax.grid(axis='y', linestyle='--', alpha=0.7)
    
    # Rotate x-tick labels for better readability
    ax.set_xticks(range(len(classifiers)))  # Set x-ticks to classifiers
    ax.set_xticklabels(classifiers, rotation=45)  # Rotate x-tick labels

# Remove any unused subplots
for i in range(len(types), len(axes)):
    fig.delaxes(axes[i])

# Adjust space between subplots
plt.subplots_adjust(wspace=0.6, hspace=0.6)

plt.savefig("G-mean_performance_plots.png", dpi=300, bbox_inches='tight')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data preparation
types = ['Type I', 'Type II', 'Type III', 'Type IV', 'Type V', 'Type VI', 'Type VII', 'Type VIII']
classifiers = ['NB', 'SVM', 'MLP', 'CatBoost', 'TabNet']

# Accuracy values for each type and classifier
accuracy_values = {
    'Type I': [91.62, 91.17, 94.32, 93.66, 92.91],
    'Type II': [75.92, 93.62, 90.26, 90.26, 95.57],
    'Type III': [86.96, 88.07, 94.54, 93.6, 99.18],
    'Type IV': [76.54, 90.24, 92.29, 84.09, 92.79],
    'Type V': [84.45, 85.09, 85, 94.84, 100],
    'Type VI': [84.45, 84.45, 93.62, 94.67, 97.6],
    'Type VII': [84.78, 87, 87.38, 95.33, 96],
    'Type VIII': [91.17, 90.24, 93, 86, 100]
}

# Creating subplots based on types
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(12, 6))
axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easy iteration

# Loop through the types and their Accuracy values
for ax, type_name in zip(axes, types):
    ax.bar(classifiers, accuracy_values[type_name], color='maroon')
    ax.set_title(f'Accuracy for {type_name}')
    ax.set_ylim(60, 100)  # Set y-axis limits for consistency
    #ax.set_xlabel('Classifier')
    ax.set_ylabel('Accuracy (%)')
    ax.grid(axis='y', linestyle='--', alpha=0.7)
    
    # Rotate x-tick labels for better readability
    ax.set_xticks(range(len(classifiers)))  # Set x-ticks to classifiers
    ax.set_xticklabels(classifiers, rotation=45)  # Rotate x-tick labels

# Remove any unused subplots
for i in range(len(types), len(axes)):
    fig.delaxes(axes[i])

# Adjust space between subplots
plt.subplots_adjust(wspace=0.6, hspace=0.6)

plt.savefig("Accuracy_performance_plots.png", dpi=300, bbox_inches='tight')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Defining the data for the table
data = {
    'Type': ['I', 'II', 'III', 'IV', 'V', 'VI', 'VII', 'VIII'],
    'MSE': [4.7e-6, 2.19e-5, 5.5e-6, 1e-5, 2.9e-4, 1.34e-3, 9.7e-4, 7.59e-4],
    'RMSE': [2.16e-3, 4.68e-3, 2.35e-3, 3.17e-3, 5.39e-2, 3.67e-2, 3.11e-3, 2.75e-2],
    'MAE': [1.19e-3, 2.69e-3, 1.57e-3, 1.51e-3, 1.9e-2, 1.97e-2, 1.98e-3, 1.7e-2],
    'RMSLE': [1.08e-3, 1.55e-3, 5.86e-4, 6.33e-4, 7.93e-2, 5.21e-3, 3.9e-3, 3.06e-3],
    'RRMSE': [2.16e-3, 2.34e-3, 7.81e-4, 7.91e-4, 1.03e-2, 6.1e-3, 4.52e-3, 3.44e-3],
    'MAPE': [1.19e-3, 1.35e-3, 5.24e-4, 3.79e-4, 3.08e-2, 3.29e-3, 2.83e-3, 2.12e-3]
}

# Create DataFrame
df = pd.DataFrame(data)

# Define figure and subplots layout
fig, axes = plt.subplots(2, 3, figsize=(20, 12))
axes = axes.flatten()  # Flatten for easy iteration

# Define metrics to plot
metrics = ['MSE', 'RMSE', 'MAE', 'RMSLE', 'RRMSE', 'MAPE']

# Plot each metric in its own subplot
for i, metric in enumerate(metrics):
    ax = axes[i]
    ax.plot(df['Type'], df[metric], marker='*', markersize=18, linewidth=2.5, linestyle='-', color='red', label=metric)
    ax.scatter(df['Type'], df[metric], color='orange', s=100, label='Marker')  # Different color for markers
    ax.set_title(metric, fontsize=18, fontweight='bold')
    ax.set_xlabel('Type', fontsize=16, fontweight='bold')
    ax.set_ylabel('Score', fontsize=16, fontweight='bold')
    
    # Set logarithmic scale for the y-axis
    ax.set_yscale('log')
    
    # Set bold and large font for ticks
    ax.tick_params(axis='x', labelsize=14, width=2, labelcolor='black')
    ax.tick_params(axis='y', labelsize=14, width=2, labelcolor='black')

# Adjust spacing between subplots
plt.subplots_adjust(hspace=0.4, wspace=0.3)

# Save the figure
#plt.savefig("error_metrics_logarithmic_subplots.png", dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
types = ["I", "II", "III", "IV", "V", "VI", "VII", "VIII"]
mse = [4.7e-6, 2.19e-5, 5.5e-6, 1e-5, 2.9e-4, 1.34e-3, 9.7e-4, 7.59e-4]
rmse = [2.16e-3, 4.68e-3, 2.35e-3, 3.17e-3, 5.39e-2, 3.67e-2, 3.11e-3, 2.75e-2]
mae = [1.19e-3, 2.69e-3, 1.57e-3, 1.51e-3, 1.9e-2, 1.97e-2, 1.98e-3, 1.7e-2]
rmsle = [1.08e-3, 1.55e-3, 5.86e-4, 6.33e-4, 7.93e-2, 5.21e-3, 3.9e-3, 3.06e-3]
rrmse = [2.16e-3, 2.34e-3, 7.81e-4, 7.91e-4, 1.03e-2, 6.1e-3, 4.52e-3, 3.44e-3]
mape = [1.19e-3, 1.35e-3, 5.24e-4, 3.79e-4, 3.08e-2, 3.29e-3, 2.83e-3, 2.12e-3]

# Set up subplots
metrics = [mse, rmse, mae, rmsle, rrmse, mape]
metric_names = ["MSE", "RMSE", "MAE", "RMSLE", "RRMSE", "MAPE"]

fig, axs = plt.subplots(2, 3, figsize=(15, 6))
axs = axs.ravel()  # Flatten the 2x3 grid of axes

# Plot each metric as a bar plot
for i, metric in enumerate(metrics):
    axs[i].bar(types, metric, color='m')
    axs[i].set_title(metric_names[i])
    axs[i].set_yscale('log')  # Logarithmic scale for y-axis
    axs[i].set_xlabel("Type")
    #axs[i].set_ylabel("Value")

# Adjust spacing between subplots
plt.subplots_adjust(hspace=0.5, wspace=0.3)

# Save the figure
plt.savefig("error_metrics_logarithmic_subplots.png", dpi=300, bbox_inches='tight')
plt.tight_layout()
plt.show()
